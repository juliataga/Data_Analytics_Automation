# %%
# Leap Year

year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("Its a leap year")
else:
    print("Its not a leap year")
# Out:
# Enter a year:  2025
# Its not a leap year

# %%
# login authentication

user = "Jules"
passkey = "Jules22@"
username = input("Enter your username: ")
password = input("Enter your password: ")

if username == user and password == passkey:
    print("Welcome to your page")
elif username == user and password != passkey:
    print("Password is not matching")
else:
    print("Username is incorrect")
# Out:
# Enter your username:  Jules
# Enter your password:  haidh
# Password is not matching

# %%
# Admission Eligibilty
print("Enter marks of PCM")

math = int(input("Enter marks for Mathematic: "))
phy = int(input("Enter marks for Physics: "))
che = int(input("Enter marks for Chemistry: "))

sum = math + phy + che
mathphy = math +phy

if (math >= 65 and phy >= 55 and che >= 50 and sum >= 180) or mathphy >= 140:
    print("student is eligible for admission")
else:
    print("student is not eligible for admission")
# Out:
# Enter marks of PCM
# Enter marks for Mathematic:  12
# Enter marks for Physics:  22
# Enter marks for Chemistry:  12
# student is not eligible for admission
