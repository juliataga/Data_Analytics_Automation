# %%
# write a python program to build a simple calculator

# Operations: 

# Addition, Substraction, Multiplication, Division, Average

# %%
operation = int(input("Choose operations: 1 - Addition, 2 - Substraction, 3 - Multiplication, 4 - Division, 5 - Average: "))

def addition():
    sum =
